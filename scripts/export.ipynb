# %%
from lib.pkg import localfile

localfile.print_source("../go/ossekaiserver", ".go")
# Out:
# # ../go/ossekaiserver/cmd/ginapiserver/main.go
# ```
# package main
#
# import (
# 	"log"
# 	"ossekaiserver/internal/ginapi"
#
# 	"github.com/gin-contrib/cors"
# 	"github.com/gin-gonic/gin"
# )
#
# func main() {
# 	r := gin.Default()
#
# 	config := cors.DefaultConfig()
# 	config.AllowOrigins = []string{"http://localhost:5173"}
# 	config.AllowHeaders = append(config.AllowHeaders, "Authorization")
# 	config.AllowMethods = []string{"GET", "POST", "PUT", "PATCH", "DELETE", "HEAD", "OPTIONS"}
# 	config.AllowCredentials = true
#
# 	r.Use(cors.New(config))
#
# 	ginapi.AddQARoutes(r)
# 	log.Println("🚀 Server listening at: http://localhost:3000")
# 	err := r.Run("localhost:3000")
# 	if err != nil {
# 		log.Fatal(err)
# 	}
# }
#
# ```
#
# # ../go/ossekaiserver/cmd/ginapiserver/main_test.go
# ```
# package main
#
# import (
# 	"testing"
# )
#
# func TestMain(t *testing.T) {
# 	main()
# }
#
# ```
#
# # ../go/ossekaiserver/internal/auth/entities.go
# ```
# package auth
#
# type Token string
#
# ...

# %%
import os
os.getcwd()
# Out:
# '/workspaces/mictlan/scripts'
