# %%
from lib.pkg import localfile

localfile.print_source("../php/koemade/internal/auth/", ".php")
# Out:
# # ../php/koemade/internal/auth/entities.php
# ```
# <?php
#
# namespace auth;
#
# class Role
# {
#     public string $value;
#     public const ADMIN = 'admin';
#     public const ACTOR = 'actor';
#     public const GUEST = 'guest';
#
#     public function __construct(string $value)
#     {
#         $roles = [self::ADMIN, self::ACTOR, self::GUEST];
#         if (!in_array($value, $roles, true)) {
#             throw new \InvalidArgumentException("invalid value: $value allowed values are: " . implode(', ', $roles));
#         }
#         $this->value = $value;
#     }
#
#     function __toString(): string
#     {
#         return $this->value;
#     }
# }
#
# class Username extends \common\Email
# {
# }
#
#
# class Password
# {
#     private string $hash;
#
#     public function __construct(string $password, bool $needsHashing = true)
#     {
#         if ($needsHashing) {
#             $this->setPassword($password);
#         } else {
# ...

# %%
import os
os.getcwd()
# Out:
# '/workspaces/mictlan/scripts'
