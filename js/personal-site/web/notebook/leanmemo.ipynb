# %% [markdown]
# # Lean 4
#
# _x: Nat を受け取って、x + 5: Nat を返す関数は、**カーリーハワード同形対応により定理である**。_
#
# _型チェックを通っているので、**Nat から Nat が導けることが証明されている**。_
#
# # Memo
#
# 定理ハブみたいなんがあると定理大量生産してたらクソみたいなのでもどっかで約に立つかもしれん
#
# - [AMC12 の問題](https://artofproblemsolving.com/wiki/index.php/2023_AMC_12B_Problems/Problem_23)の証明を lean で書きたい
#
# - 天使と悪魔と人間がいて、天使はいつも正しいこと、悪魔はいつも逆、人間はランダムな回答をする。
#   ２つ階段があって、片方地獄行き、もう片方は天国行き。
#   二回の質問で天国行きの階段を特定する質問を考える。
#   一回目に、回答者以外の二人のうち人間がどちらか確認して、二回目に人間じゃないと言われた方に二重質問すれば正しい階段が特定できる。
#   これの証明を lean で書きたい。
